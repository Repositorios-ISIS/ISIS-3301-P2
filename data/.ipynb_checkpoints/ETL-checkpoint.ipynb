# %% [markdown]
# ![](banner.png)
# # Objetivos
# + Cargar los datos de una base de datos oltp y hacer las transformaciones necesarias para convertir esa información al modelo dimensional
#
# # Carga de librerias

# %%
#Librerias para trabajar los datos
import pandas as pd
import numpy as np

# %%
#Carga de los datos principales
fact_table = pd.read_csv('data_deptos.csv',sep=',',index_col=False,low_memory=False)

# %% [markdown]
# # Creación de dimensiones y tabla de hechos
# ## Creación dimensión Fecha

# %%
#Creamos el dataframe
df_fecha = pd.DataFrame(fact_table["anio"].unique())
df_fecha = df_fecha.reset_index()
df_fecha.columns = ["fecha_key", "anio"]
df_fecha["fecha_key"] = df_fecha["fecha_key"]+1

#Actualizamos la tabla principal
fact_table = pd.merge(fact_table, df_fecha, on="anio")
fact_table = fact_table.drop(columns=['anio'])

# %%
fact_table.head(5)
# Out:
#       sexo      edad  codigo_depto nombre_depto  codigo_evento  \
# 0  Hombres  0-4 años             5    Antioquia            101
# 1  Hombres  0-4 años             5    Antioquia            103
# 2  Hombres  0-4 años             5    Antioquia            105
# 3  Hombres  0-4 años             5    Antioquia            106
# 4  Hombres  0-4 años             5    Antioquia            109
#
#                                            evento   c/1000  c/10000  c/100000  \
# 0           ENFERMEDADES INFECCIOSAS INTESTINALES  0.00386  0.03859   0.38594
# 1  CIERTAS ENF. TRANSMITIDAS POR VECTORES Y RABIA  0.00386  0.03859   0.38594
# 2                                      MENINGITIS  0.00772  0.07719   0.77187
# 3                                      SEPTICEMIA  0.00386  0.03859   0.38594
# 4                INFECCIONES RESPIRATORIAS AGUDAS  0.03473  0.34734   3.47343
#
#    fecha_key
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
#Guardamos la dimensión fecha
df_fecha.to_csv('dim_fecha.csv',index = False)

# %% [markdown]
# ## Creación dimensión Perfil

# %%
#obtengo edades y sexo unicas, luego creo a para hacer un join sin parametro
list_edad = pd.DataFrame(fact_table["edad"].unique())
list_edad["a"] = "a"
list_sexo = pd.DataFrame(fact_table["sexo"].unique())
list_sexo["a"] = "a"

# %%
r1 = pd.merge(list_edad, list_sexo, on="a")
r1.head(5)
# Out:
#           0_x  a      0_y
# 0    0-4 años  a  Hombres
# 1    0-4 años  a  Mujeres
# 2  15-44 años  a  Hombres
# 3  15-44 años  a  Mujeres
# 4  45-64 años  a  Hombres

# %%
#Creamos el dataframe
df_perfil = r1.copy()
df_perfil = df_perfil.drop(columns=['a'])
df_perfil = df_perfil.reset_index()
df_perfil.columns = ["perfil_key","edad", "sexo"]
df_perfil["perfil_key"] = df_perfil["perfil_key"]+1

# %%
df_perfil.head(5)
# Out:
#    perfil_key        edad     sexo
# 0           1    0-4 años  Hombres
# 1           2    0-4 años  Mujeres
# 2           3  15-44 años  Hombres
# 3           4  15-44 años  Mujeres
# 4           5  45-64 años  Hombres

# %%
#Actualizamos la tabla principal
fact_table = pd.merge(fact_table, df_perfil,  on=['edad','sexo'])
fact_table = fact_table.drop(columns=['edad','sexo'])
fact_table
# Out:
#        codigo_depto nombre_depto  codigo_evento  \
# 0                 5    Antioquia            101
# 1                 5    Antioquia            103
# 2                 5    Antioquia            105
# 3                 5    Antioquia            106
# 4                 5    Antioquia            109
# ...             ...          ...            ...
# 44864            99      Vichada            302
# 44865            99      Vichada            306
# 44866            99      Vichada            307
# 44867            99      Vichada            605
# 44868            99      Vichada            608
#
#                                                evento   c/1000  c/10000  \
# 0               ENFERMEDADES INFECCIOSAS INTESTINALES  0.00386  0.03859
# 1      CIERTAS ENF. TRANSMITIDAS POR VECTORES Y RABIA  0.00386  0.03859
# 2                                          MENINGITIS  0.00772  0.07719
# 3                                          SEPTICEMIA  0.00386  0.03859
# 4                    INFECCIONES RESPIRATORIAS AGUDAS  0.03473  0.34734
# ...                                               ...      ...      ...
# 44864                      ENFERMEDADES HIPERTENSIVAS  0.26918  2.69179
# 44865                          INSUFICIENCIA CARDIACA  0.26918  2.69179
# 44866                  ENFERMEDADES CEREBROVASCULARES  0.26918  2.69179
# 44867      ENF. CRONICAS VIAS REPIRATORIAS INFERIORES  0.53836  5.38358
# 44868                OTRAS ENFERMEDADES RESPIRATORIAS  0.26918  2.69179
#
#        c/100000  fecha_key  perfil_key
# 0       0.38594          1           1
# 1       0.38594          1           1
# 2       0.77187          1           1
# 3       0.38594          1           1
# 4       3.47343          1           1
# ...         ...        ...         ...
# 44864  26.91790          8          10
# 44865  26.91790          8          10
# 44866  26.91790          8          10
# 44867  53.83580          8          10
# 44868  26.91790          8          10
#
# [44869 rows x 9 columns]

# %%
#Guardamos la dimensión perfil
df_perfil.to_csv('dim_perfil.csv',index = False)

# %% [markdown]
# ## Creación dimensión Lugar

# %%
df_temp = fact_table.copy()

# %%
df_lugar = df_temp[["codigo_depto","nombre_depto"]]

# %%
df_lugar = df_lugar.drop_duplicates()

# %%
#Creamos el dataframe
df_lugar = df_lugar.reset_index()
df_lugar.columns = ["lugar_key","codigo_depto","nombre_depto"]
df_lugar["lugar_key"] = df_lugar["lugar_key"]+1

# %%
#Para departamentos a añadir las latitudes y las longitudes
depto = pd.read_csv('colombia_depto.csv', header=None, encoding='utf8') 
depto.columns = ["codigo_depto","nombre_depto","lati_depto", "long_depto"]
depto = depto.drop(columns=["nombre_depto"])

# %%
df_lugar = pd.merge(df_lugar, depto, on='codigo_depto')

# %%
#luego lo "desarreglamos"
df_lugar["lati_depto"] = df_lugar["lati_depto"].apply(lambda x : str(x))
df_lugar["long_depto"] = df_lugar["long_depto"].apply(lambda x : str(x))

#Arreglamos pa que todo quede con comas
df_lugar["lati_depto"] = df_lugar["lati_depto"].apply(lambda x : x.replace(".",","))
df_lugar["long_depto"] = df_lugar["long_depto"].apply(lambda x : x.replace(".",","))

# %%
df_lugar.head()
# Out:
#    lugar_key  codigo_depto nombre_depto lati_depto   long_depto
# 0          1             5    Antioquia        7,0        -75,5
# 1         61             8    Atlántico      10,75        -75,0
# 2        166            13      Bolívar        9,0  -74,3333333
# 3        210            15       Boyacá        5,5        -72,5
# 4        247            17       Caldas       5,25        -75,5

# %%
#Actualizamos la tabla principal
fact_table = pd.merge(fact_table, df_lugar,  on=['nombre_depto'], suffixes = ("_l","_r"))
fact_table = fact_table.drop(columns=['codigo_depto_l', 'codigo_depto_r', 'nombre_depto','lati_depto','long_depto'])
fact_table
# Out:
#        codigo_evento                                          evento   c/1000  \
# 0                101           ENFERMEDADES INFECCIOSAS INTESTINALES  0.00386
# 1                103  CIERTAS ENF. TRANSMITIDAS POR VECTORES Y RABIA  0.00386
# 2                105                                      MENINGITIS  0.00772
# 3                106                                      SEPTICEMIA  0.00386
# 4                109                INFECCIONES RESPIRATORIAS AGUDAS  0.03473
# ...              ...                                             ...      ...
# 42685            302                      ENFERMEDADES HIPERTENSIVAS  0.26918
# 42686            306                          INSUFICIENCIA CARDIACA  0.26918
# 42687            307                  ENFERMEDADES CEREBROVASCULARES  0.26918
# 42688            605      ENF. CRONICAS VIAS REPIRATORIAS INFERIORES  0.53836
# 42689            608                OTRAS ENFERMEDADES RESPIRATORIAS  0.26918
#
#        c/10000  c/100000  fecha_key  perfil_key  lugar_key
# 0      0.03859   0.38594          1           1          1
# 1      0.03859   0.38594          1           1          1
# 2      0.07719   0.77187          1           1          1
# 3      0.03859   0.38594          1           1          1
# 4      0.34734   3.47343          1           1          1
# ...        ...       ...        ...         ...        ...
# 42685  2.69179  26.91790          8          10       1079
# 42686  2.69179  26.91790          8          10       1079
# 42687  2.69179  26.91790          8          10       1079
# 42688  5.38358  53.83580          8          10       1079
# 42689  2.69179  26.91790          8          10       1079
#
# [42690 rows x 8 columns]

# %%
#Guardamos la dimensión lugar
df_lugar.to_csv('dim_lugar.csv',index = False, sep = ";")

# %% [markdown]
# ## Creación dimensión Evento

# %%
df_temp = fact_table.copy()

# %%
df_evento = df_temp[["codigo_evento","evento"]]

# %%
#Creamos el dataframe
df_evento = df_evento.reset_index()
df_evento.columns = ["evento_key","codigo_evento","evento"]
df_evento["evento_key"] = df_evento["evento_key"]+1

#Actualizamos la tabla principal
fact_table = pd.merge(fact_table, df_evento, on="evento")
fact_table = fact_table.drop(columns=['evento', 'codigo_evento'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19512/3402768990.py in <module>
#       6 #Actualizamos la tabla principal
#       7 fact_table = pd.merge(fact_table, df_evento, on="evento")
# ----> 8 fact_table = fact_table.drop(columns=['evento', 'codigo_evento'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['codigo_evento'] not found in axis"

# %%
fact_table

# %%
#Guardamos la dimensión fecha
df_evento.to_csv('dim_evento.csv',index = False)

# %%
#Guardamos la tabla de hechos
fact_table.to_csv('fact_table.csv',index = False)
